# %%
import os
import pandas as pd
dfs2 = pd.read_csv('Gender_Data.csv')

# %%
dfs2['last name'] = "NULL"

# %%
dfs2['race'] = "indian"

# %%
dfs2['Status'] = "Current"

# %%
dfs2['age'] = 0
dfs2['eID'] = 0
dfs2['comp_ID'] = 0

# %%
1200, 1000000
# Out:
# (1200, 1000000)

# %%
import random
ind = 0
for e in dfs2['eID']:
    dfs2['eID'][ind] = random.randrange(1000001, 2000000, 7)
    ind += 1
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
dfs2['eID']
# Out:
# 0        1491394
# 1        1411384
# 2        1221621
# 3        1947038
# 4        1513206
# 5        1686869
# 6        1658519
# 7        1731592
# 8        1301197
# 9        1395102
# 10       1236678
# 11       1890394
# 12       1853938
# 13       1303801
# 14       1728351
# 15       1585005
# 16       1422997
# 17       1953198
# 18       1276732
# 19       1024116
# 20       1154911
# 21       1936706
# 22       1505184
# 23       1554023
# 24       1155303
# 25       1892564
# 26       1474195
# 27       1168050
# 28       1771226
# 29       1068167
#           ...
# 53952    1198248
# 53953    1685266
# 53954    1083833
# 53955    1750499
# 53956    1232968
# 53957    1176107
# 53958    1930427
# 53959    1407492
# 53960    1352003
# 53961    1579006
# 53962    1276158
# 53963    1295016
# 53964    1229748
# 53965    1110783
# 53966    1677804
# 53967    1259442
# 53968    1164431
# 53969    1981142
# 53970    1931099
# 53971    1229426
# 53972    1465249
# ...

# %%
ind = 0
for e in dfs2['age']:
    dfs2['age'][ind] = random.randrange(18, 60, 2)
    ind += 1
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df = pd.read_csv('companies_from_reviews.csv')
df
# Out:
#                                    Name  Count
# 0       Tata-Consultancy-Services-(tcs)  14441
# 1       Tata-Consultancy-Services-(tcs)  14441
# 2       Tata-Consultancy-Services-(tcs)  14441
# 3       Tata-Consultancy-Services-(tcs)  14441
# 4       Tata-Consultancy-Services-(tcs)  14441
# 5       Tata-Consultancy-Services-(tcs)  14441
# 6       Tata-Consultancy-Services-(tcs)  14441
# 7       Tata-Consultancy-Services-(tcs)  14441
# 8       Tata-Consultancy-Services-(tcs)  14441
# 9       Tata-Consultancy-Services-(tcs)  14441
# 10      Tata-Consultancy-Services-(tcs)  14441
# 11      Tata-Consultancy-Services-(tcs)  14441
# 12      Tata-Consultancy-Services-(tcs)  14441
# 13      Tata-Consultancy-Services-(tcs)  14441
# 14      Tata-Consultancy-Services-(tcs)  14441
# 15      Tata-Consultancy-Services-(tcs)  14441
# 16      Tata-Consultancy-Services-(tcs)  14441
# 17      Tata-Consultancy-Services-(tcs)  14441
# 18      Tata-Consultancy-Services-(tcs)  14441
# ...

# %%
df = df.drop_duplicates(subset=['Name'])
for inde, item in df.iterrows():
    print(item['Name'])
# Out:
# Tata-Consultancy-Services-(tcs)
# IBM
# Infosys
# Accenture
# Cognizant-Technology-Solutions
# Hdfc-Bank
# Capgemini
# Amazon.com
# L&T-Technology-Services-Ltd.
# Concentrix
# Axis-Bank
# HSBC
# HP
# Hinduja-Global-Solutions
# Dell-Technologies
# Deloitte
# Bharti-Airtel-Limited
# Mphasis
# Teleperformance
# Oracle
# Ey
# Kotak-Mahindra-Bank
# Sutherland
# Ericsson
# Wns-Global-Services
# JPMorgan-Chase
# Reliance-Industries-Ltd
# Muthoot-Finance
# Bosch
# Jio
# Nokia
# Vodafoneziggo
# Honeywell
# Icici-Prudential-Life-Insurance
# Citi
# UnitedHealth-Group
# Mahindra-&-Mahindra-Ltd
# American-Express
# Kpmg
# Standard-Chartered-Bank
# Barclays
# Maersk
# Deutsche-Bank
# Flipkart.com
# Yes-Bank
# Hyatt
# Apollo-Hospitals
# Marriott-International,-Inc.
# Wells-Fargo
# Microsoft
# Google
# DHL
# Tata-Aia-Life
# Jll
# Alstom
# Ride.swiggy
# Byju's
# Facebook
# Indeed

# %%
for row, item in df.iterrows():
    for i in range(1, item['Count']):
        while True:
            agent = random.randint(0, 53981)
            if dfs2['comp_ID'][agent] == 0:
                break
        dfs2['comp_ID'][agent] = item['Name']
dfs2
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-60767c39aab8> in <module>()
#       3         while True:
# ...

# %%
dfs2
# Out:
#                Name  Gender last name    race   Status  age      eID  \
# 0             Aaban       0      NULL  indian  Current   30  1491394
# 1          Aabharan       0      NULL  indian  Current   42  1411384
# 2            Aabhas       0      NULL  indian  Current   56  1221621
# 3            Aabhat       0      NULL  indian  Current   34  1947038
# 4           Aabheer       0      NULL  indian  Current   28  1513206
# 5            Abheer       0      NULL  indian  Current   28  1686869
# 6            Aabher       0      NULL  indian  Current   18  1658519
# 7              Aabi       0      NULL  indian  Current   34  1731592
# 8          Aabilesh       0      NULL  indian  Current   48  1301197
# 9             Aabir       0      NULL  indian  Current   22  1395102
# 10         Aabishan       0      NULL  indian  Current   50  1236678
# 11       Aabishayan       0      NULL  indian  Current   36  1890394
# 12         Aacharya       0      NULL  indian  Current   48  1853938
# ...

# %%
dfs2.to_excel('new_emplyees.xlsx', index = False)

# %%
dfs3 = pd.read_excel('emp_ID_comp_ID.xls', index = False)

# %%
dfs4 = pd.read_csv('Company_latest.csv')

# %%
dfsnew = pd.read_excel('new_emplyees.xlsx', index = False)
el = dfsnew['eID']

# %%
cl = dfsnew['comp_ID']

# %%
dfs4.columns
dfsnew
# Out:
#                Name  Gender  last name    race   Status  age      eID  \
# 0             Aaban       0        NaN  indian  Current   30  1491394
# 1          Aabharan       0        NaN  indian  Current   42  1411384
# 2            Aabhas       0        NaN  indian  Current   56  1221621
# 3            Aabhat       0        NaN  indian  Current   34  1947038
# 4           Aabheer       0        NaN  indian  Current   28  1513206
# 5            Abheer       0        NaN  indian  Current   28  1686869
# 6            Aabher       0        NaN  indian  Current   18  1658519
# 7              Aabi       0        NaN  indian  Current   34  1731592
# 8          Aabilesh       0        NaN  indian  Current   48  1301197
# 9             Aabir       0        NaN  indian  Current   22  1395102
# 10         Aabishan       0        NaN  indian  Current   50  1236678
# 11       Aabishayan       0        NaN  indian  Current   36  1890394
# ...

# %%
cl[0]
dict = {}
for index, k in dfs4.iterrows():
        dict[k['Company_Name']] = k['Company_ID']

# %%
j = 0
for i in cl:
    cl[j] = dict[cl[j]]
    j += 1
cl
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0           1
# 1        1072
# 2         970
# 3        1072
# 4        1072
# 5        1072
# 6         970
# 7         970
# 8           6
# 9        1072
# 10         37
# 11          6
# 12          6
# 13          6
# 14         37
# 15        970
# 16        970
# 17          6
# 18          1
# 19       1072
# 20        970
# 21        970
# 22         37
# 23        970
# 24       1072
# 25        970
# 26       1072
# 27        970
# 28         37
# 29          1
#          ...
# 53952       6
# 53953     970
# 53954       1
# 53955     970
# 53956    1072
# 53957      37
# ...

# %%
row_to_add = pd.DataFrame({'eID':el, 
                           'comp_ID':cl,
                         })
ds = pd.read_excel('emp_ID_comp_ID.xls', index = False)
d = ds.append(row_to_add, ignore_index=True)
d.to_excel('emp_ID_comp_ID_4.xlsx', index = False)

# %%
d
# Out:
#       comp_ID      eID
# 0           0   955524
# 1        3706   384306
# 2       11573   460629
# 3        1573   428680
# 4        3520   549331
# 5        1993   246711
# 6         922   511947
# 7        8813   817127
# 8        9335   894022
# 9        4337   761861
# 10       6266   788550
# 11       3169   879161
# 12       5147    18041
# 13       1352   557281
# 14       8579    49758
# 15       2747   685600
# 16       2562    86631
# 17        219   336387
# 18       1631   152108
# 19       2553   421630
# 20      14193    42494
# 21      12038   971974
# 22       2402   504695
# 23       7844   447787
# 24       3910   938611
# 25      10166   830991
# 26       5643   264567
# 27       6921   164210
# 28       2630   226957
# 29         21   376572
# ...       ...      ...
# 90743       6  1198248
# 90744     970  1685266
# 90745       1  1083833
# 90746     970  1750499
# 90747    1072  1232968
# 90748      37  1176107
# 90749     970  1930427
# 90750       1  1407492
# ...
