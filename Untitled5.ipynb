# %%
import os
import pandas as pd

#dir='/Users/richagupta/Desktop/DBMS_project/data_file_review.xlsx'
#excelFile=os.path.join(dir)
dfs = pd.read_excel('data_file_review_2.xlsx',index=False,sheet_name=0,header=0)
#rl = []
#print(dfs.head(10))
#start = 1
#for cmpy in dfs['URL']:
#    for item in returnList:
#        if(cmpy == item[0]):
#            rl.append(item[0])
#            break
#    start += 1
#print(start)
#print(rl)

# %%
dfs2 = pd.read_csv('Company_latest.csv')

# %%
del dfs['company_id']

# %%
dfs2.columns
# Out:
# Index([u'Company_Name', u'Company_ID'], dtype='object')

# %%
dfs2['URL']=dfs2['Company_Name']

# %%
dfs2
# Out:
#                                             Company_Name  Company_ID  \
# 0                                              Cognizant           1
# 1                Prime India Healhcare Solutions Pvt Ltd           2
# 2                                         ABC Recruiters           3
# 3                      Nine Square Marketing Consultants           4
# 4                                                   Flex           5
# 5                                              Accenture           6
# 6                               Yashus Digital Marketing           7
# 7                                                Genpact           8
# 8                                          Signal Expert           9
# 9                                        CGI Group, Inc.          10
# 10                              Inspire Global Solutions          11
# 11                                           Wells Fargo          12
# 12                                        KS ENTERPRISES          13
# ...

# %%
dfse.columns
# Out:
# Index([u'URL', u'Rating', u'CompleteReview', u'ReviewDetails', u'ReviewTitle',
#        u'Company_ID'],
#       dtype='object')

# %%
dfse
# Out:
#                             URL  Rating  \
# 0       Reliance Industries Ltd       3
# 1       Reliance Industries Ltd       3
# 2       Reliance Industries Ltd       5
# 3       Reliance Industries Ltd       5
# 4       Reliance Industries Ltd       1
# 5       Reliance Industries Ltd       3
# 6       Reliance Industries Ltd       5
# 7                       Mphasis       1
# 8                          Kpmg       4
# 9       Reliance Industries Ltd       5
# 10      Reliance Industries Ltd       1
# 11      Reliance Industries Ltd       2
# 12                     Yes Bank       4
# 13                      Mphasis       4
# 14                      Mphasis       4
# 15                      Mphasis       5
# 16                         Kpmg       2
# 17                         Kpmg       4
# 18                         Kpmg       3
# 19      Reliance Industries Ltd       5
# 20      Reliance Industries Ltd       5
# 21      Reliance Industries Ltd       5
# ...

# %%
dfs['company_id']=0

# %%
dfse=pd.merge(dfs,dfs2,how='left',on=["URL"])

# %%
del dfse['Company_Name']

# %%
dfs['company_id'][dfs['URL']=='Reliance Industries Ltd']=1
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfse.to_excel('data_file_review_4.xlsx',index=False)

# %%
dfs
